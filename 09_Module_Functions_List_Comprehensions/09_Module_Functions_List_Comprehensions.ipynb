# %%
import math
import re
from collections import Counter

# %%
# Exercises: Level 1

# 1. Declare a function add_two_numbers. It takes two parameters and it returns a sum.
def add_two_numbers(num1, num2):
    return num1 + num2

# 2. Area of a circle is calculated as follows: area = π x r x r. Write a function that calculates area_of_circle.
def area_of_circle(radius):
    return math.pi * radius * radius

# 3. Write a function called add_all_nums which takes arbitrary number of arguments and sums all the arguments.
# Check if all the list items are number types. If not do give a reasonable feedback.
def add_all_nums(*args):
    for arg in args:
        if not isinstance(arg, (int, float)):
            return "All arguments must be numbers."
    return sum(args)

# 4. Temperature in °C can be converted to °F using this formula: °F = (°C x 9/5) + 32.
# Write a function which converts °C to °F, convert_celsius_to_fahrenheit.
def convert_celsius_to_fahrenheit(celsius):
    return (celsius * 9/5) + 32

# 5. Write a function called check-season, it takes a month parameter and returns the season: Autumn, Winter, Spring or Summer.
def check_season(month):
    month = month.lower()
    if month in ['december', 'january', 'february']:
        return "Winter"
    elif month in ['march', 'april', 'may']:
        return "Spring"
    elif month in ['june', 'july', 'august']:
        return "Summer"
    elif month in ['september', 'october', 'november']:
        return "Autumn"
    else:
         return "Invalid month"

# 6. Write a function called calculate_slope which return the slope of a linear equation
def calculate_slope(x1, y1, x2, y2):
    if x2 - x1 == 0:
        return "Undefined (vertical line)"
    return (y2 - y1) / (x2 - x1)

# 7. Quadratic equation is calculated as follows: ax² + bx + c = 0.
# Write a function which calculates solution set of a quadratic equation, solve_quadratic_eqn.
def solve_quadratic_eqn(a, b, c):
    delta = b**2 - 4*a*c
    if delta > 0:
        x1 = (-b + math.sqrt(delta)) / (2*a)
        x2 = (-b - math.sqrt(delta)) / (2*a)
        return x1, x2
    elif delta == 0:
        x = -b / (2*a)
        return x
    else:
        return "No real roots"

# 8. Declare a function named print_list. It takes a list as a parameter and it prints out each element of the list.
def print_list(my_list):
    for item in my_list:
        print(item)

# 9. Declare a function named reverse_list. It takes an array as a parameter and it returns the reverse of the array (use loops).
def reverse_list(my_list):
    reversed_list = []
    for i in range(len(my_list) - 1, -1, -1):
        reversed_list.append(my_list[i])
    return reversed_list

# 10. Declare a function named capitalize_list_items. It takes a list as a parameter and it returns a capitalized list of items
def capitalize_list_items(my_list):
    return [item.capitalize() for item in my_list]

# 11. Declare a function named add_item. It takes a list and an item parameters. It returns a list with the item added at the end.
def add_item(my_list, item):
    my_list.append(item)
    return my_list

# 12. Declare a function named remove_item. It takes a list and an item parameters. It returns a list with the item removed from it.
def remove_item(my_list, item):
    if item in my_list:
        my_list.remove(item)
    return my_list

# 13. Declare a function named sum_of_numbers. It takes a number parameter and it adds all the numbers in that range.
def sum_of_numbers(number):
    return sum(range(1, number + 1))

# 14. Declare a function named sum_of_odds. It takes a number parameter and it adds all the odd numbers in that range.
def sum_of_odds(number):
    return sum(i for i in range(1, number + 1) if i % 2 != 0)

# 15. Declare a function named sum_of_even. It takes a number parameter and it adds all the even numbers in that - range.
def sum_of_even(number):
    return sum(i for i in range(1, number + 1) if i % 2 == 0)

# %%
# Exercises: Level 2

# 1. Declare a function named evens_and_odds . It takes a positive integer as parameter and it counts number of evens and odds in the number.
def evens_and_odds(number):
    odds_count = 0
    evens_count = 0
    for i in range(1,number + 1):
        if i % 2 == 0:
            evens_count += 1
        else:
            odds_count += 1
    print(f"The number of odds are {odds_count}.")
    print(f"The number of evens are {evens_count}.")

# 2. Call your function factorial, it takes a whole number as a parameter and it return a factorial of the number
def factorial(number):
    if number == 0:
        return 1
    else:
        result = 1
        for i in range(1, number + 1):
            result *= i
        return result

# 3. Call your function is_empty, it takes a parameter and it checks if it is empty or not
def is_empty(parameter):
    if not parameter:
        return True
    else:
        return False

# 4. Write different functions which take lists. They should calculate_mean, calculate_median, calculate_mode,
#    calculate_range, calculate_variance, calculate_std (standard deviation).

def calculate_mean(my_list):
    if not my_list:
        return None
    return sum(my_list) / len(my_list)

def calculate_median(my_list):
    my_list.sort()
    n = len(my_list)
    if n % 2 == 0:
        mid1 = my_list[n//2 - 1]
        mid2 = my_list[n//2]
        median = (mid1 + mid2) / 2
    else:
        median = my_list[n//2]
    return median

def calculate_mode(my_list):
    counts = Counter(my_list)
    max_count = max(counts.values())
    modes = [key for key, value in counts.items() if value == max_count]
    return modes

def calculate_range(my_list):
  if not my_list:
    return None
  return max(my_list) - min(my_list)

def calculate_variance(my_list):
    if not my_list:
        return None
    n = len(my_list)
    mean = sum(my_list) / n
    variance = sum((x - mean) ** 2 for x in my_list) / n
    return variance

def calculate_std(my_list):
    variance = calculate_variance(my_list)
    if variance is None:
        return None
    return math.sqrt(variance)

# %%
# Exercises: Level 3

# 1. Write a function called is_prime, which checks if a number is prime.
def is_prime(number):
    if number <= 1:
        return False
    if number <= 3:
        return True
    if number % 2 == 0 or number % 3 == 0:
        return False
    for i in range(5, int(math.sqrt(number)) + 1, 6):
        if number % i == 0 or number % (i + 2) == 0:
            return False
    return True

# 2. Write a functions which checks if all items are unique in the list.
def are_items_unique(my_list):
    return len(my_list) == len(set(my_list))

# 3. Write a function which checks if all the items of the list are of the same data type.
def are_items_same_type(my_list):
  if not my_list:
    return True
  first_type = type(my_list[0])
  return all(isinstance(item, first_type) for item in my_list)

# 4. Write a function which check if provided variable is a valid python variable
def is_valid_variable(variable):
    return bool(re.match("^[a-zA-Z_][a-zA-Z0-9_]*$", variable))

# 5 & 6 . Go to the data folder and access the countries-data.py file.
# Create a function called the most_spoken_languages in the world. It should return 10 or 20 most spoken languages in the world in descending order
# Create a function called the most_populated_countries. It should return 10 or 20 most populated countries in descending order.
import sys
sys.path.append('./data') # import the file if it is in data folder
from countries_data import countries

def most_spoken_languages(num_languages):
    languages_count = {}
    for country in countries:
        if 'languages' in country:
            for language in country['languages']:
                if language in languages_count:
                    languages_count[language] += 1
                else:
                    languages_count[language] = 1
    sorted_languages = sorted(languages_count.items(), key=lambda item: item[1], reverse=True)
    return sorted_languages[:num_languages]

def most_populated_countries(num_countries):
    sorted_countries = sorted(countries, key=lambda country: country.get('population',0), reverse=True)
    return sorted_countries[:num_countries]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-b94ca94ec930> in <cell line: 0>()
#      34 import sys
#      35 sys.path.append('./data') # import the file if it is in data folder
# ---> 36 from countries_data import countries
#      37
#      38 def most_spoken_languages(num_languages):
#
# ModuleNotFoundError: No module named 'countries_data'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Test cases:
print("Level 1 Tests:")
print("add_two_numbers(5, 3):", add_two_numbers(5, 3))
print("area_of_circle(5):", area_of_circle(5))
print("add_all_nums(1, 2, 3, 4, 5):", add_all_nums(1, 2, 3, 4, 5))
print("add_all_nums(1, 2, 'a', 4):", add_all_nums(1, 2, 'a', 4))
print("convert_celsius_to_fahrenheit(25):", convert_celsius_to_fahrenheit(25))
print("check_season('january'):", check_season('january'))
print("check_season('July'):", check_season('July'))
print("check_season('October'):", check_season('October'))
print("check_season('bla'):", check_season('bla'))
print("calculate_slope(1, 2, 3, 6):", calculate_slope(1, 2, 3, 6))
print("calculate_slope(1, 2, 1, 6):", calculate_slope(1, 2, 1, 6))
print("solve_quadratic_eqn(1, -3, 2):", solve_quadratic_eqn(1, -3, 2))
print("solve_quadratic_eqn(1, 4, 4):", solve_quadratic_eqn(1, 4, 4))
print("solve_quadratic_eqn(1, 1, 1):", solve_quadratic_eqn(1, 1, 1))
print("print_list([1, 2, 3]):", print_list([1, 2, 3]))
print("reverse_list([1, 2, 3, 4, 5]):", reverse_list([1, 2, 3, 4, 5]))
print("reverse_list(['A', 'B', 'C']):", reverse_list(['A', 'B', 'C']))
print("capitalize_list_items(['apple', 'banana', 'cherry']):", capitalize_list_items(['apple', 'banana', 'cherry']))
food_staff = ['Potato', 'Tomato', 'Mango', 'Milk']
print("add_item(food_staff, 'Meat'):", add_item(food_staff.copy(), 'Meat'))
numbers = [2, 3, 7, 9]
print("add_item(numbers, 5):", add_item(numbers.copy(), 5))
food_staff = ['Potato', 'Tomato', 'Mango', 'Milk']
print("remove_item(food_staff, 'Mango'):", remove_item(food_staff.copy(), 'Mango'))
numbers = [2, 3, 7, 9]
print("remove_item(numbers, 3):", remove_item(numbers.copy(), 3))
print("sum_of_numbers(5):", sum_of_numbers(5))
print("sum_of_numbers(10):", sum_of_numbers(10))
print("sum_of_numbers(100):", sum_of_numbers(100))
print("sum_of_odds(10):", sum_of_odds(10))
print("sum_of_even(10):", sum_of_even(10))

# %%
print("\nLevel 2 Tests:")
evens_and_odds(100)
print("factorial(5):", factorial(5))
print("is_empty([]):", is_empty([]))
print("is_empty([1,2,3]):", is_empty([1,2,3]))
print("calculate_mean([1, 2, 3, 4, 5]):", calculate_mean([1, 2, 3, 4, 5]))
print("calculate_median([1, 2, 3, 4, 5]):", calculate_median([1, 2, 3, 4, 5]))
print("calculate_median([1, 2, 3, 4]):", calculate_median([1, 2, 3, 4]))
print("calculate_mode([1, 2, 2, 3, 3, 3]):", calculate_mode([1, 2, 2, 3, 3, 3]))
print("calculate_range([1, 2, 3, 4, 5]):", calculate_range([1, 2, 3, 4, 5]))
print("calculate_variance([1, 2, 3, 4, 5]):", calculate_variance([1, 2, 3, 4, 5]))
print("calculate_std([1, 2, 3, 4, 5]):", calculate_std([1, 2, 3, 4, 5]))

# %%
print("\nLevel 3 Tests:")
print("is_prime(7):", is_prime(7))
print("is_prime(10):", is_prime(10))
print("are_items_unique([1, 2, 3, 4, 5]):", are_items_unique([1, 2, 3, 4, 5]))
print("are_items_unique([1, 2, 3, 2, 5]):", are_items_unique([1, 2, 3, 2, 5]))
print("are_items_same_type([1, 2, 3, 4, 5]):", are_items_same_type([1, 2, 3, 4, 5]))
print("are_items_same_type([1, 2, '3', 4, 5]):", are_items_same_type([1, 2, '3', 4, 5]))
print("is_valid_variable('my_var'):", is_valid_variable('my_var'))
print("is_valid_variable('1my_var'):", is_valid_variable('1my_var'))
print("most_spoken_languages(10):", most_spoken_languages(10))
print("most_populated_countries(10):", most_populated_countries(10))
